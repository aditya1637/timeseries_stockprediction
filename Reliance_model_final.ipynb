# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import yfinance as yf
from datetime import date
import warnings
warnings.filterwarnings('ignore')

# %%
end = date.today().strftime("%Y-%m-%d")
df = yf.download('RELIANCE.NS', start='2010-01-01', end=end)
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
df
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2010-01-04   498.814209   498.814209   467.155457   491.682404   440.421967
# 2010-01-05   525.695618   525.695618   487.065033   489.488007   438.456360
# 2010-01-06   493.693939   500.368591   489.465149   497.397003   445.540771
# 2010-01-07   497.397003   509.740479   492.825348   505.648834   452.932343
# 2010-01-08   506.540314   509.191895   501.054321   504.323059   451.744812
# ...                 ...          ...          ...          ...          ...
# 2024-08-06  2910.300049  2955.000000  2902.649902  2912.100098  2912.100098
# 2024-08-07  2938.000000  2945.000000  2923.000000  2929.649902  2929.649902
# 2024-08-08  2915.050049  2930.000000  2891.850098  2898.250000  2898.250000
# 2024-08-09  2920.000000  2953.000000  2912.000000  2948.600098  2948.600098
# 2024-08-12  2940.000000  2946.000000  2915.500000  2921.250000  2921.250000
#
#               Volume
# Date
# 2010-01-04  38323043
# 2010-01-05  10696412
# 2010-01-06  11845880
# 2010-01-07  13098960
# 2010-01-08   7555074
# ...              ...
# 2024-08-06   5118093
# 2024-08-07   4087284
# 2024-08-08   6193596
# 2024-08-09   3124888
# 2024-08-12   4092292
#
# [3604 rows x 6 columns]

# %%
reliance = df.drop(['Adj Close'], axis=1)
reliance
# Out:
#                    Open         High          Low        Close    Volume
# Date
# 2010-01-04   498.814209   498.814209   467.155457   491.682404  38323043
# 2010-01-05   525.695618   525.695618   487.065033   489.488007  10696412
# 2010-01-06   493.693939   500.368591   489.465149   497.397003  11845880
# 2010-01-07   497.397003   509.740479   492.825348   505.648834  13098960
# 2010-01-08   506.540314   509.191895   501.054321   504.323059   7555074
# ...                 ...          ...          ...          ...       ...
# 2024-08-06  2910.300049  2955.000000  2902.649902  2912.100098   5118093
# 2024-08-07  2938.000000  2945.000000  2923.000000  2929.649902   4087284
# 2024-08-08  2915.050049  2930.000000  2891.850098  2898.250000   6193596
# 2024-08-09  2920.000000  2953.000000  2912.000000  2948.600098   3124888
# 2024-08-12  2940.000000  2946.000000  2915.500000  2921.250000   4092292
#
# [3604 rows x 5 columns]

# %%
reliance.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 3604 entries, 2010-01-04 to 2024-08-12
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Open    3604 non-null   float64
#  1   High    3604 non-null   float64
#  2   Low     3604 non-null   float64
#  3   Close   3604 non-null   float64
#  4   Volume  3604 non-null   int64
# dtypes: float64(4), int64(1)
# memory usage: 168.9 KB

# %%
reliance.describe()
# Out:
#               Open         High          Low        Close        Volume
# count  3604.000000  3604.000000  3604.000000  3604.000000  3.604000e+03
# mean   1086.811062  1098.242988  1074.719762  1086.019218  8.996012e+06
# std     822.346714   830.008173   814.291269   822.028822  6.212072e+06
# min     308.587280   312.153198   307.695831   309.090179  0.000000e+00
# 25%     428.176292   433.119415   423.090309   427.439102  5.477004e+06
# 50%     610.031342   614.705872   604.202484   608.499847  7.401654e+06
# 75%    1863.213348  1891.364777  1840.126801  1854.940948  1.036059e+07
# max    3208.899902  3217.600098  3171.000000  3201.800049  9.432482e+07

# %% [markdown]
# # EDA

# %%
reliance.duplicated().sum()
# Out:
# 0

# %%
reliance.isnull().sum()
# Out:
# Open      0
# High      0
# Low       0
# Close     0
# Volume    0
# dtype: int64

# %%
# Creating Box Plots

# %%
plt.figure(figsize=(20,10))

# Plot 1
plt.subplot(2,2,1)
plt.boxplot(reliance['Open'])
plt.xlabel('Date')
plt.ylabel('Open Price')
plt.title('Open')

# Plot 2
plt.subplot(2,2,2)
plt.boxplot(reliance['Close'])
plt.xlabel('Date')
plt.ylabel('Close Price')
plt.title('Close')

# Plot 3
plt.subplot(2,2,3)
plt.boxplot(reliance['High'])
plt.xlabel('Date')
plt.ylabel('High Price')
plt.title('High')

# Plot 4
plt.subplot(2,2,4)
plt.boxplot(reliance['Low'])
plt.xlabel('Date')
plt.ylabel('Low Price')
plt.title('Low')
# Out:
# Text(0.5, 1.0, 'Low')

# %%
# From the Boxplot it is observed that there are no outliers in the dataset

# %% [markdown]
# # Visualization

# %%
import seaborn as sns

# %%
sns.set_style(style='darkgrid')

# %%
plt.figure(figsize=(20,10))

# Plot 1
plt.subplot(2,2,1)
plt.plot(reliance['Open'],color='green')
plt.xlabel('Date')
plt.ylabel('Open Price')
plt.title('Open')

# Plot 2
plt.subplot(2,2,2)
plt.plot(reliance['Close'],color='red')
plt.xlabel('Date')
plt.ylabel('Close Price')
plt.title('Close')

# Plot 3
plt.subplot(2,2,3)
plt.plot(reliance['High'],color='blue')
plt.xlabel('Date')
plt.ylabel('High Price')
plt.title('High')

# Plot 4
plt.subplot(2,2,4)
plt.plot(reliance['Low'],color='orange')
plt.xlabel('Date')
plt.ylabel('Low Price')
plt.title('Low')
# Out:
# Text(0.5, 1.0, 'Low')

# %%
# Histogram

# %%
plt.figure(figsize=(20,10))

# Plot 1
plt.subplot(2,2,1)
plt.hist(reliance['Open'],bins=50,color='green')
plt.xlabel('Open Price')
plt.ylabel('Frequency')
plt.title('Open')

# Plot 2
plt.subplot(2,2,2)
plt.hist(reliance['Close'],bins=50,color='red')
plt.xlabel('Close Price')
plt.ylabel('Frequency')
plt.title('Close')

# Plot 3
plt.subplot(2,2,3)
plt.hist(reliance['High'],bins=50,color='blue')
plt.xlabel('High Price')
plt.ylabel('Frequency')
plt.title('High')

# Plot 4
plt.subplot(2,2,4)
plt.hist(reliance['Low'],bins=50,color='orange')
plt.xlabel('Low Price')
plt.ylabel('Frequency')
plt.title('Low')
# Out:
# Text(0.5, 1.0, 'Low')

# %%
# KDE Plots

# %%
plt.figure(figsize=(20,10))

#Plot 1
plt.subplot(2,2,1)
sns.kdeplot(reliance['Open'], color='green')
plt.title('Open')

#Plot 2
plt.subplot(2,2,2)
sns.kdeplot(reliance['Close'], color='red')
plt.title('Close')

#Plot 3
plt.subplot(2,2,3)
sns.kdeplot(reliance['High'], color='green')
plt.title('High')

#Plot 4
plt.subplot(2,2,4)
sns.kdeplot(reliance['Low'], color='red')
plt.title('Low')
# Out:
# Text(0.5, 1.0, 'Low')

# %%
plt.figure(figsize=(20,10))
plt.plot(reliance['Volume'])
plt.xlabel('Date')
plt.ylabel('Volume')
plt.title('Date vs Volume')
plt.show()

# %%
# Moving Average

# %%
rel_ma = reliance.copy()
rel_ma['MA 30 day'] = rel_ma['Close'].rolling(window=30).mean()
rel_ma['MA 100 day'] = rel_ma['Close'].rolling(window=100).mean()
rel_ma
# Out:
#                    Open         High          Low        Close    Volume  \
# Date
# 2010-01-04   498.814209   498.814209   467.155457   491.682404  38323043
# 2010-01-05   525.695618   525.695618   487.065033   489.488007  10696412
# 2010-01-06   493.693939   500.368591   489.465149   497.397003  11845880
# 2010-01-07   497.397003   509.740479   492.825348   505.648834  13098960
# 2010-01-08   506.540314   509.191895   501.054321   504.323059   7555074
# ...                 ...          ...          ...          ...       ...
# 2024-08-06  2910.300049  2955.000000  2902.649902  2912.100098   5118093
# 2024-08-07  2938.000000  2945.000000  2923.000000  2929.649902   4087284
# 2024-08-08  2915.050049  2930.000000  2891.850098  2898.250000   6193596
# 2024-08-09  2920.000000  2953.000000  2912.000000  2948.600098   3124888
# 2024-08-12  2940.000000  2946.000000  2915.500000  2921.250000   4092292
#
#               MA 30 day   MA 100 day
# Date
# 2010-01-04          NaN          NaN
# 2010-01-05          NaN          NaN
# 2010-01-06          NaN          NaN
# 2010-01-07          NaN          NaN
# 2010-01-08          NaN          NaN
# ...                 ...          ...
# 2024-08-06  3072.998364  2955.812505
# 2024-08-07  3073.710026  2955.530503
# 2024-08-08  3069.383358  2955.181003
# 2024-08-09  3065.633358  2955.158503
# 2024-08-12  3058.648356  2955.727502
#
# [3604 rows x 7 columns]

# %%
plt.figure(figsize=(20,10))
plt.plot(rel_ma['MA 30 day'],label='30 day')
plt.plot(rel_ma['Close'],label='Original data')
plt.legend(loc='upper left')
plt.xlabel('Date')
plt.ylabel('Price')
plt.title('Actual Close vs Moving Average 30 day')
plt.show()

# %%
plt.figure(figsize=(20,10))
plt.plot(rel_ma['MA 100 day'],label='100 day')
plt.plot(rel_ma['Close'],label='Original data')
plt.legend(loc='upper left')
plt.xlabel('Date')
plt.ylabel('Price')
plt.title('Actual Close vs Moving Average 100 day')
plt.show()

# %%
# Long term and short term trends can be identified by Moving Average.
# There was huge downfall in 2020,may be for covid-19
# Long term trend is in higher side

# %%
plt.figure(figsize=(20,8))

# Candle Chart
plt.subplot(3,3,1)
plt.title('Candle Stick Chart')
plt.plot(reliance.index, reliance['Close'], color='black')
plt.fill_between(reliance.index, reliance['Open'], reliance['Close'], where = reliance['Close']>=reliance['Open'], color='green', alpha=0.4)
plt.fill_between(reliance.index, reliance['Open'], reliance['Close'], where= reliance['Close']<reliance['Open'], color='red', alpha=0.4)
plt.grid(True)

# Mountain Chart
plt.subplot(3,3,2)
plt.title('Mountain Chart')
plt.fill_between(reliance.index, reliance['Close'], color='black', alpha=0.3)
plt.grid(True)


# Color HCL Chart
plt.subplot(3,3,3)
plt.title('Color HCL Bar')
plt.fill_between(reliance.index, reliance['Close'], color='skyblue', alpha=0.5)
plt.plot(reliance['Close'], color='blue')
plt.grid(True)

plt.subplot(3,3,4)
plt.title('Histogram')
plt.hist(reliance['Close'], bins=30, color='orange')
plt.grid(True)

# Vertex Chart
plt.subplot(3,3,5)
plt.title('Vertex Chart')
plt.scatter(reliance.index, reliance['Close'], color='cyan', s=5)
plt.grid(True)

# Step Chart
plt.subplot(3,3,6)
plt.title('Step Chart')
plt.step(reliance.index, reliance['Close'], color='red')
plt.grid(True)

plt.tight_layout() 
plt.show()

# %%
reliance
# Out:
#                    Open         High          Low        Close    Volume
# Date
# 2010-01-04   498.814209   498.814209   467.155457   491.682404  38323043
# 2010-01-05   525.695618   525.695618   487.065033   489.488007  10696412
# 2010-01-06   493.693939   500.368591   489.465149   497.397003  11845880
# 2010-01-07   497.397003   509.740479   492.825348   505.648834  13098960
# 2010-01-08   506.540314   509.191895   501.054321   504.323059   7555074
# ...                 ...          ...          ...          ...       ...
# 2024-08-06  2910.300049  2955.000000  2902.649902  2912.100098   5118093
# 2024-08-07  2938.000000  2945.000000  2923.000000  2929.649902   4087284
# 2024-08-08  2915.050049  2930.000000  2891.850098  2898.250000   6193596
# 2024-08-09  2920.000000  2953.000000  2912.000000  2948.600098   3124888
# 2024-08-12  2940.000000  2946.000000  2915.500000  2921.250000   4092292
#
# [3604 rows x 5 columns]

# %% [markdown]
# # Model Building

# %% [markdown]
# ## Prophet

# %%
data = df[['Close']]
data
# Out:
#                   Close
# Date
# 2010-01-04   491.682404
# 2010-01-05   489.488007
# 2010-01-06   497.397003
# 2010-01-07   505.648834
# 2010-01-08   504.323059
# ...                 ...
# 2024-08-06  2912.100098
# 2024-08-07  2929.649902
# 2024-08-08  2898.250000
# 2024-08-09  2948.600098
# 2024-08-12  2921.250000
#
# [3604 rows x 1 columns]

# %%
data.reset_index(inplace=True)

# %%
data.rename(columns={'Date':'ds', 'Close':'y'}, inplace=True)
data
# Out:
#              ds            y
# 0    2010-01-04   491.682404
# 1    2010-01-05   489.488007
# 2    2010-01-06   497.397003
# 3    2010-01-07   505.648834
# 4    2010-01-08   504.323059
# ...         ...          ...
# 3599 2024-08-06  2912.100098
# 3600 2024-08-07  2929.649902
# 3601 2024-08-08  2898.250000
# 3602 2024-08-09  2948.600098
# 3603 2024-08-12  2921.250000
#
# [3604 rows x 2 columns]

# %%
from prophet import Prophet
model_pr = Prophet()

# %%
model_pr.fit(data)
# Out:
# 22:47:15 - cmdstanpy - INFO - Chain [1] start processing
# 22:47:16 - cmdstanpy - INFO - Chain [1] done processing

# %%
# Checking Seasonality
model_pr.component_modes
# Out:
# {'additive': ['yearly',
#   'weekly',
#   'additive_terms',
#   'extra_regressors_additive',
#   'holidays'],
#  'multiplicative': ['multiplicative_terms', 'extra_regressors_multiplicative']}

# %%
future_date = model_pr.make_future_dataframe(periods=30)
future_date.tail()
# Out:
#              ds
# 3629 2024-09-07
# 3630 2024-09-08
# 3631 2024-09-09
# 3632 2024-09-10
# 3633 2024-09-11

# %%
forecast = model_pr.predict(future_date)
forecast.tail(30)
# Out:
#              ds        trend   yhat_lower   yhat_upper  trend_lower  \
# 3604 2024-08-13  2807.186649  2683.636332  2960.840412  2807.186649
# 3605 2024-08-14  2807.866892  2682.520203  2956.958571  2807.866892
# 3606 2024-08-15  2808.547135  2688.746169  2964.787955  2808.547135
# 3607 2024-08-16  2809.227378  2686.971385  2967.574307  2809.227378
# 3608 2024-08-17  2809.907621  2679.964291  2969.022331  2809.907621
# 3609 2024-08-18  2810.587863  2710.371095  2993.649147  2810.587863
# 3610 2024-08-19  2811.268106  2679.023612  2954.797393  2811.268106
# 3611 2024-08-20  2811.948349  2681.036543  2973.738245  2811.948349
# 3612 2024-08-21  2812.628592  2693.545029  2965.016113  2812.628592
# 3613 2024-08-22  2813.308835  2692.850645  2962.943776  2813.308835
# 3614 2024-08-23  2813.989078  2692.675702  2976.794821  2813.989078
# 3615 2024-08-24  2814.669321  2692.313907  2958.820841  2814.669321
# 3616 2024-08-25  2815.349564  2721.792528  2993.911724  2815.349564
# 3617 2024-08-26  2816.029806  2687.421305  2975.421052  2816.029806
# 3618 2024-08-27  2816.710049  2691.944246  2962.407292  2816.710049
# 3615                         0.0  2825.701120
# 3616                         0.0  2853.629477
# 3617                         0.0  2830.644438
# 3618                         0.0  2833.095553
# 3619                         0.0  2832.056762
# 3620                         0.0  2834.314202
# 3621                         0.0  2833.262217
# 3622                         0.0  2831.956101
# 3623                         0.0  2860.005402
# 3624                         0.0  2837.113764
# 3625                         0.0  2839.629627
# 3626                         0.0  2838.625535
# 3627                         0.0  2840.885994
# 3628                         0.0  2839.803570
# 3629                         0.0  2838.431736
# 3630                         0.0  2866.378318
# 3631                         0.0  2843.345474
# 3632                         0.0  2845.680557
# 3633                         0.0  2844.455571

# %%
fig = model_pr.plot(forecast)
plt.title('Reliance Stock Price Prediction for Next 30 Days using Prophet')
plt.xlabel('Date')
plt.ylabel('Price')
plt.show()

# %%
# In this Graph:
# 1. The Black scatter plot is our actual data.
# 2. The Blue lineplot is the prediction.

# %%
fig2 = model_pr.plot_components(forecast)

# %%
# In this Graph:
# 1. It is basically checking the seasonality of the data.
# 2. Prophet have taken seasonality for weekly and yearly.

# %%
# Cross Validation
from prophet.diagnostics import cross_validation

# %%
df_cv = cross_validation(model_pr, initial='730 days', period='180 days', horizon='365 days')
# Out:
#   0%|          | 0/24 [00:00<?, ?it/s]
# 22:47:19 - cmdstanpy - INFO - Chain [1] start processing
# 22:47:19 - cmdstanpy - INFO - Chain [1] done processing
# 22:47:19 - cmdstanpy - INFO - Chain [1] start processing
# 22:47:19 - cmdstanpy - INFO - Chain [1] done processing
# 22:47:20 - cmdstanpy - INFO - Chain [1] start processing
# 22:47:20 - cmdstanpy - INFO - Chain [1] done processing
# 22:47:20 - cmdstanpy - INFO - Chain [1] start processing
# 22:47:20 - cmdstanpy - INFO - Chain [1] done processing
# 22:47:20 - cmdstanpy - INFO - Chain [1] start processing
# 22:47:21 - cmdstanpy - INFO - Chain [1] done processing
# 22:47:21 - cmdstanpy - INFO - Chain [1] start processing
# 22:47:21 - cmdstanpy - INFO - Chain [1] done processing
# 22:47:22 - cmdstanpy - INFO - Chain [1] start processing
# 22:47:22 - cmdstanpy - INFO - Chain [1] done processing
# 22:47:22 - cmdstanpy - INFO - Chain [1] start processing
# 22:47:23 - cmdstanpy - INFO - Chain [1] done processing
# 22:47:23 - cmdstanpy - INFO - Chain [1] start processing
# 22:47:23 - cmdstanpy - INFO - Chain [1] done processing
# 22:47:24 - cmdstanpy - INFO - Chain [1] start processing
# 22:47:24 - cmdstanpy - INFO - Chain [1] done processing
# 22:47:25 - cmdstanpy - INFO - Chain [1] start processing
# 22:47:25 - cmdstanpy - INFO - Chain [1] done processing
# 22:47:26 - cmdstanpy - INFO - Chain [1] start processing
# 22:47:26 - cmdstanpy - INFO - Chain [1] done processing
# 22:47:26 - cmdstanpy - INFO - Chain [1] start processing
# 22:47:27 - cmdstanpy - INFO - Chain [1] done processing
# 22:47:28 - cmdstanpy - INFO - Chain [1] start processing
# 22:47:28 - cmdstanpy - INFO - Chain [1] done processing
# 22:47:29 - cmdstanpy - INFO - Chain [1] start processing
# 22:47:30 - cmdstanpy - INFO - Chain [1] done processing
# 22:47:30 - cmdstanpy - INFO - Chain [1] start processing
# 22:47:31 - cmdstanpy - INFO - Chain [1] done processing

# %%
# 1. model: The Prophet model that has been fitted to the data.

# 2. initial: The size of the initial training period. 
#             This is the duration from the start of the time series data to the first cutoff point.

# 3. period: The spacing between cutoff dates.
#            This defines how often the model will be retrained and tested on a new subset of data.

# 4. horizon: The forecast horizon. 
#             This is the duration for which the forecast is made from each cutoff point.

# %%
df_cv.head()

# %%
from prophet.diagnostics import performance_metrics

# %%
df_p = performance_metrics(df_cv)
df_p

# %%
# 1. MDAPE = Mean Directional Accuracy Percentage Error.
# 2. MAPE = Mean Absolute Percentage Error.
# 3. sMAPE = Symmetric Mean Absolute Percentage Error.
# 4. Coverage is basically difference between yhat lower and yhat upper.

# %%
from prophet.plot import plot_cross_validation_metric

# %%
fig3 = plot_cross_validation_metric(df_cv, metric='rmse')

# %%
# This plot is trend with respect to error and it is plotted for RMSE.

# %%
# Checking Seasonality

from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.tsa.stattools import adfuller,acf,pacf
from statsmodels.tsa.arima_model import ARIMA
period=365
result= seasonal_decompose(df['Close'],model='multiplicative',period=period)

# %%
result.seasonal.plot()

# %%
result.trend.plot()

# %%
result.resid.plot()

# %%
# Our data is seasonal

# %%
# conducting dickey fuller test to check stationary.

# %%
from statsmodels.tsa.stattools import adfuller

# %%
test_result = adfuller(df['Close'])

# %%
# ho: The data is not stationary.
# ha: The data is stationary.

# %%
def adfullet_test(Close):
    result = adfuller(Close)
    labels = ['ADF Test', 'P-value', 'Lags Used', 'Number Of Observation']
    for value, label in zip(result, labels):
        print(label + ': ' + str(value))
    if result[1] <= 0.05:
        print("Null Hypothesis is rejected. The data is Stationary")
    else:
        print("Null Hypothesis is accepted. The data is not Stationary")

# %%
adfullet_test(df['Close'])

# %%
# The assumption is rejected. (0.99 !<= 0.05)

# %%
# Differenceing

# %%
df['Close_Diff'] = df['Close'] - df['Close'].shift(12)

# %%
df.head(20)

# %%
adfullet_test(df['Close_Diff'].dropna())

# %%
plt.figure(figsize=(10,7))
df['Close_Diff'].plot()

# %%
from pandas.plotting import autocorrelation_plot
autocorrelation_plot(df['Close'])
plt.show()

# %%
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
import statsmodels.api as sm

# %%
# Autocorrelation
fig = plt.figure(figsize=(12,8))
ax1 = fig.add_subplot(211)
fig = sm.graphics.tsa.plot_acf(df['Close_Diff'].iloc[13:],lags=40,ax=ax1)

# Partial Autocorrelation
ax2 = fig.add_subplot(212)
fig = sm.graphics.tsa.plot_pacf(df['Close_Diff'].iloc[13:],lags=40,ax=ax2)  
plt.show()

# %%
# Seasonal and Non_seasonal components are marked

# %% [markdown]
# # Sarimax

# %%
from statsmodels.tsa.statespace.sarimax import SARIMAX
import warnings
warnings.filterwarnings('ignore')

# %%
data2 = df[['Close']]
data2

# %%
from sklearn.preprocessing import StandardScaler
scale = StandardScaler()
data2['Close'] = scale.fit_transform(data2[['Close']])

# %%
model = SARIMAX(data2, order=(1,1,1), seasonal_order=(1,1,1,12))
model

# %%
model_fit = model.fit(disp=False) 
print(model_fit.summary())

# %%
forecast_steps = 30
forecast = model_fit.get_forecast(steps=forecast_steps)
forecast_index = pd.date_range(start=data2.index[-1], periods=forecast_steps + 1, freq='D')[1:]
forecast_values = scale.inverse_transform(forecast.predicted_mean.values.reshape(-1, 1))

# %%
forecast_df = pd.DataFrame(data=forecast_values, index=forecast_index, columns=['Forecast'])
forecast_df

# %%
plt.figure(figsize=(14,7))
sns.scatterplot(forecast_df, s=100)
plt.xlabel('Date')
plt.ylabel('Forecast')
plt.title('Forecast Data')
plt.show()

# %%
plt.figure(figsize=(14, 7))
plt.plot(forecast_df, color='orange', linestyle='--', marker='*')
plt.xlabel('Date')
plt.ylabel('Forecast')
plt.title('Forecast Data')
plt.show()

# %%
plt.figure(figsize=(14, 7))
plt.plot(data2.index, scale.inverse_transform(data2), label='Actual')
plt.plot(forecast_df.index, forecast_df['Forecast'], label='Forecast')
plt.title('Reliance Stock Price Prediction for Next 30 Days using SARIMAX')
plt.xlabel('Date')
plt.ylabel('Price')
plt.legend()
plt.show()

# %%
# Calculate RMSE

# %%
from sklearn.metrics import mean_squared_error
actual = data2['Close'][1:]
predicted = model_fit.fittedvalues[1:]

rmse = np.sqrt(mean_squared_error(actual, predicted))
print(f"Root Mean Squared Error (RMSE): {rmse:.4f}")

# %%
# Calculate MSE

# %%
from sklearn.metrics import mean_squared_error
actual = data2['Close'][1:]
predicted = model_fit.fittedvalues[1:]

mse = mean_squared_error(actual, predicted)
print(f"Root Mean Squared Error (RMSE): {mse:.4f}")

# %%
# Calculate MAE

# %%
from sklearn.metrics import mean_absolute_error
actual = data2['Close'][1:]  
predicted = model_fit.fittedvalues[1:]

mae = mean_absolute_error(actual, predicted)
print(f"Mean Absolute Error (MAE): {mae:.4f}")

# %%
# Calculate MAPE

# %%
actual = data2['Close'][1:]  
predicted = model_fit.fittedvalues[1:]
mape = np.mean(np.abs((actual - predicted) / actual)) * 100
print(f"Mean Absolute Percentage Error (MAPE): {mape:.2f}%")

# %%
dict_err = {
    'MSE': [0.0008 ],
    
    'MAE': [0.0162 ],

    'RMSE': [0.0276],

    'MAPE': [6.90 ]
}

# %%
df_err = pd.DataFrame(dict_err,index=['SARIMAX'])
df_err

# %%
# The errors in Prophet model are much higher side than SARIMAX,hence the deployment can be done with SARIMAX

# %%
file = 'model.pkl'

# %%
import pickle

# %%
pickle.dump(model,open(file,'wb'))

# %%
# Supriya: Dataset and EDA (1 to 11)
# Shreyash: Visualization (12 to 25)
# Tanu: Prophet (26 to 38)
# Indranil: Cross Validation (39 to 49)
# Aditya: Seasonality (50 to 69)
# Rupa: Sarimax (70 to end)
# Milind: Deployment
